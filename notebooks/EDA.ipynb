# %%
#importação das bibliotecas

import pandas as pd
import plotly.express as px
import streamlit as st

# %%
#importação dos dados

dados = pd.read_csv("C:/Users/fabi_/projeto5/V_OCORRENCIA_AMPLA.csv", sep=";")

#fonte dos dados: https://dados.gov.br/dados/conjuntos-dados/ocorrencias-aeronauticas

# %%
#identificação da estrutura dos dados

print(dados.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5021 entries, 0 to 5020
# Data columns (total 45 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Numero_da_Ocorrencia              5021 non-null   int64
#  1   Numero_da_Ficha                   5019 non-null   object
#  2   Operador_Padronizado              4945 non-null   object
#  3   Classificacao_da_Ocorrencia       5021 non-null   object
#  4   Data_da_Ocorrencia                5021 non-null   object
#  5   Hora_da_Ocorrencia                3588 non-null   object
#  6   Municipio                         3627 non-null   object
#  7   UF                                5018 non-null   object
#  8   Regiao                            4351 non-null   object
#  9   Descricao_do_Tipo                 4379 non-null   object
#  10  ICAO                              1687 non-null   object
# ...

# %%
#visualização dos dados

primeiras_linhas = dados.head(10)
primeiras_linhas.to_csv('amostra.csv', index=False, sep=',')

# %%
#identificando valores únicas em coluna com códigos de aeronaves

print(dados['Categoria_da_Aeronave'].unique())
print(dados['Categoria_da_Aeronave'].nunique())
# Out:
# ['PET' 'ADE' 'PRI' 'TPP' 'S11' 'M48' 'Estrangeira' 'AMD' nan 'S05' 'TPX'
#  'D15' 'M43' 'M35' 'S09' 'M25' 'ADF' 'TPR' 'S59' 'T11' 'M14' 'D13' 'D20'
#  'Sem matrícula' 'ESTRANGEIRA' 'AIF' 'PIN' 'AID' 'SAE' 'INDEFINIDA' 'PEX'
#  'S07' 'M24' 'S05S' 'M37' 'SAE-AG' 'S00' 'PRH' 'ADD' 'M42' 'M15' 'TPN'
#  'Militar' 'M16' 'M56' 'M60' 'D17' 'D08' 'D19' 'D05' 'D18' 'P50' 'S22'
#  'EX2' 'ALE' 'S82' 'M46' 'S51']
# 57

# %%
#criando colunas com as somatórias de vítimas por tipo de lesão

dados['lesoes_fatais'] = dados['Lesoes_Fatais_Tripulantes'] + dados['Lesoes_Fatais_Passageiros'] + dados['Lesoes_Fatais_Terceiros']
dados['lesoes_graves'] = dados['Lesoes_Graves_Tripulantes'] + dados['Lesoes_Graves_Passageiros'] + dados['Lesoes_Graves_Terceiros']
dados['lesoes_leves'] = dados['Lesoes_Leves_Tripulantes'] + dados['Lesoes_Leves_Passageiros'] + dados['Lesoes_Leves_Terceiros']
dados['ilesos'] = dados['Ilesos_Tripulantes'] + dados['Ilesos_Passageiros']
dados['lesoes_desconhecidas'] = dados['Lesoes_Desconhecidas_Tripulantes'] + dados['Lesoes_Desconhecidas_Passageiros'] + dados['Lesoes_Desconhecidas_Terceiros']

# %%
#seleção das colunas relevantes para a análise e padronização de seus nomes

dados_v1 = dados[['Numero_da_Ocorrencia', 'Classificacao_da_Ocorrencia', 'Data_da_Ocorrencia', 'Municipio', 'UF', 'Regiao', 'Descricao_do_Tipo', 'Categoria_da_Aeronave', 'Fase_da_Operacao', 'Operacao', 'Danos_a_Aeronave', 'Modelo', 'Nome_do_Fabricante', 'lesoes_fatais', 'lesoes_graves', 'lesoes_leves', 'ilesos', 'lesoes_desconhecidas']]
dados_v1 = dados_v1.rename(columns={
    'Numero_da_Ocorrencia' : 'numero_da_ocorrencia',
    'Classificacao_da_Ocorrencia' : 'classificacao_da_ocorrencia',
    'Data_da_Ocorrencia' : 'data_da_ocorrencia',
    'Municipio' : 'municipio',
    'UF' : 'uf',
    'Regiao' : 'regiao',
    'Descricao_do_Tipo' : 'tipo_de_ocorrencia',
    'Categoria_da_Aeronave' : 'categoria_da_aeronave',
    'Fase_da_Operacao' : 'fase_da_operacao',
    'Operacao' : 'tipo_de_operacao',
    'Danos_a_Aeronave' : 'danos_a_aeronave',
    'Modelo' : 'modelo',
    'Nome_do_Fabricante' : 'nome_do_fabricante'
})

# %%
#verificação da estrutura dos dados

print(dados_v1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5021 entries, 0 to 5020
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   numero_da_ocorrencia         5021 non-null   int64
#  1   classificacao_da_ocorrencia  5021 non-null   object
#  2   data_da_ocorrencia           5021 non-null   object
#  3   municipio                    3627 non-null   object
#  4   uf                           5018 non-null   object
#  5   regiao                       4351 non-null   object
#  6   tipo_de_ocorrencia           4379 non-null   object
#  7   categoria_da_aeronave        5012 non-null   object
#  8   fase_da_operacao             3721 non-null   object
#  9   tipo_de_operacao             4927 non-null   object
#  10  danos_a_aeronave             3595 non-null   object
#  11  modelo                       4858 non-null   object
#  12  nome_do_fabricante           4730 non-null   object
# ...

# %%
#visualização dos dados

print(dados_v1.head())
# Out:
#    numero_da_ocorrencia classificacao_da_ocorrencia data_da_ocorrencia  \
# 0                 30125                    Acidente         2021-11-07
# 1                 33226                    Acidente         2022-07-27
# 2                 28923                    Acidente         2021-07-24
# 3                 28927             Incidente Grave         2021-07-25
# 4                 37288             Incidente Grave         2023-05-16
#
#             municipio  uf    regiao  \
# 0  SÃO JOSÉ DE MIPIBU  RN  Nordeste
# 1            CONDEÚBA  BA  Nordeste
# 2       TUPI PAULISTA  SP   Sudeste
# 3   BRAGANÇA PAULISTA  SP   Sudeste
# 4      SÃO DESIDÉRIO   BA  Nordeste
#
#                                   tipo_de_ocorrencia categoria_da_aeronave  \
# 0                           PERDA DE CONTROLE EM VOO                   PET
# 1  FALHA OU MAU FUNCIONAMENTO DE SISTEMA / COMPON...                   ADE
# 2                FALHA OU MAU FUNCIONAMENTO DO MOTOR                   PET
# ...

# %%
#tratamento das colunas

dados_v1['numero_da_ocorrencia'] = dados_v1['numero_da_ocorrencia'].astype(str)
dados_v1['municipio'] = dados_v1['municipio'].str.upper()
dados_v1['fase_da_operacao'] = dados_v1['fase_da_operacao'].fillna('Não informado')
dados_v1['danos_a_aeronave'] = dados_v1['danos_a_aeronave'].fillna('Não informado')
dados_v1['data_da_ocorrencia'] = pd.to_datetime(dados_v1['data_da_ocorrencia'], format='%Y-%m-%d')
dados_v1['ano_da_ocorrencia'] = dados_v1['data_da_ocorrencia'].dt.year
dados_v1['lesoes_fatais'] = dados_v1['lesoes_fatais'].fillna(0).astype(int)
dados_v1['lesoes_graves'] - dados_v1['lesoes_graves'].fillna(0).astype(int)
dados_v1['lesoes_leves'] = dados_v1['lesoes_leves'].fillna(0).astype(int)
dados_v1['ilesos'] = dados_v1['ilesos'].fillna(0).astype(int)
dados_v1['lesoes_desconhecidas'] = dados_v1['lesoes_desconhecidas'].fillna(0).astype(int)

# %%
#criação de dicionário com os descritivos das categorias das aeronaves listadas

categorias = {
    'TPP' : 'Privada (Transporte de Pessoas e Bens sem fins lucrativos)',
    'PRI' : 'Privada Instrução (Aeroclubes e Escolas de Aviação)',
    'TPN' : 'Transporte Aéreo Não Regular (Táxi Aéreo)',
    'TPR' : 'Transporte Aéreo Regular (Linhas Aéreas Comerciais)',
    'SAE' : 'Serviço Aéreo Especializado (Aerofotogrametria, Publicidade, etc.)',
    'SAE-AG' : 'Serviço Aéreo Especializado Agrícola (Pulverização)',
    'PET' : 'Protótipo Experimental',
    'TPX' : 'Particular Experimental',
    'PEX' : 'Pesquisa e Desenvolvimento Experimental',
    'ALE' : 'Aeronave Leve Esportiva (LSA)',
    'ADE' : 'Aeronave de Demonstração',
    'ADF' : 'Aeronave de Fabricante (Testes de Voo)',
    'ADD' : 'Aeronave de Desenvolvimento',
    'AID' : 'Aeronave de Importação (Traslado ao Brasil)',
    'AIF' : 'Aeronave de Instrução de Fabricante',
    'PIN' : 'Instrução Não Regular',
    'PRH' : 'Privada Histórica',
    'Militar' : 'Aeronave de uso das Forças Armadas (FAB, Marinha, Exército)',
    'Estrangeira' : 'Aeronave com matrícula de outro país operando temporariamente',
    'INDEFINIDA' : 'Aeronave sem categoria definida no registro inicial',
    'S11' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S05' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S09' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S59' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S07' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S05S' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S00' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S22' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S82' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'S51' : 'Aeronaves Experimentais (Aeroplanos, Planadores, LE)',
    'M48' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M43' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M35' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M25' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M14' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M24' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M37' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M42' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M15' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M16' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M56' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M60' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'M46' : 'Aeronaves de Construção Amadora (Vários modelos e pesos)',
    'D15' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D13' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D20' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D17' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D08' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D19' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D05' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'D18' : 'Aeronaves de Decolagem por meios próprios / Autogiros',
    'T11' : 'Aeronave de Construção Amadora (Trike)',
    'AMD' : 'Aeronave de Montagem por Distribuidor',
    'EX2' : 'Aeronave Experimental (Categoria 2)',
    'P50' : 'Aeronave com Certificado de Autorização de Voo Experimental',
    'Sem matrícula' : 'Aeronave sem matrícula registrada no momento da ocorrência'
}

# %%
#criando coluna no dataframe com os dados das categorias

dados_v1['categoria_descritivo'] = dados_v1['categoria_da_aeronave'].map(categorias).fillna('Não informado')

# %%
#análise de valores de campos para construção de gráficos

print(dados_v1['fase_da_operacao'].unique())
print(dados_v1['classificacao_da_ocorrencia'].unique())
print(dados_v1['tipo_de_operacao'].unique())
print(dados_v1['danos_a_aeronave'].unique())

danos = {
    'Não informado' : '1 - Não informado',
    'Desconhecida' : '2 - Desconhecida',
    'Nenhum' : '3 - Nenhum',
    'Leve' : '4 - Leve',
    'Substancial' : '5 - Substancial',
    'Destruída' : '6 - Destruída'
}

dados_v1['danos_a_aeronave'] = dados_v1['danos_a_aeronave'].map(danos)

print(dados_v1['danos_a_aeronave'].unique())
# Out:
# ['Arremetida' 'Corrida após pouso' 'Cruzeiro' 'Indeterminada' 'Decolagem'
#  'Subida' 'Táxi' 'Aproximação' 'Manobra' 'Pouso' 'Não informado'
#  'Voo a baixa altura' 'Procedimento de Aproximação' 'Partida do motor'
#  'Outras' 'Circuto de Tráfego' 'Pairado' 'Descida' 'Procedimento IFR'
#  'Em rota' 'Especializada' 'Estacionamento' 'Cheque de motor ou rotor'
#  'Reta Final' 'Operação de Solo' 'Saída IFR' 'Corrida de decolagem'
#  'Emprego Segurança Pública']
# ['Acidente' 'Incidente Grave']
# ['Voo Privado' 'Voo não regular' 'Voo de Instrução' 'Operação Agrícola'
#  'Táxi Aéreo' nan 'Voo Experimental' 'Operação Pública'
#  'Operação Policial' 'Operação Especializada' 'Voo Regular' 'Desconhecida'
#  'Operação Militar']
# ['Destruída' 'Substancial' 'Leve' 'Nenhum' 'Não informado' 'Desconhecida']
# ['6 - Destruída' '5 - Substancial' '4 - Leve' '3 - Nenhum'
#  '1 - Não informado' '2 - Desconhecida']

# %%
#criando gráfico de dispersão

fig = px.scatter(dados_v1, x='ano_da_ocorrencia', y='lesoes_fatais', color='tipo_de_operacao', labels={'ano_da_ocorrencia': 'Ano da ocorrência', 'lesoes_fatais': 'Número de lesões fatais', 'tipo_de_operacao':'Tipo de operação'}, title='Quantidade de lesões fatais em acidentes aéreos por ano')
fig.show()
